# %%
# Import the modules
from sklearn.datasets import make_blobs
import pandas as pd

# %%
# Generate three synthetic clusters
X, y = make_blobs(
    centers=7, 
    n_features=2,
    random_state=1
)

# %%
# Print out the X values
X
# Out:
# array([[-1.92744799e+00,  4.93684534e+00],
#        [-5.34819391e+00,  7.80308582e+00],
#        [-6.29774524e-01,  3.91792391e+00],
#        [-2.26302640e+00,  4.60587690e+00],
#        [ 5.74590017e-01,  1.80802909e+00],
#        [-6.31183320e+00,  8.38635435e+00],
#        [-6.94306091e+00, -7.02374420e+00],
#        [-7.36970762e+00, -2.91940303e+00],
#        [-4.00629630e+00,  8.67340543e+00],
#        [-5.42863512e+00, -3.94830140e+00],
#        [-1.12089839e+00,  3.52968685e+00],
#        [-6.90484511e+00, -7.27705918e+00],
#        [-1.98197711e+00,  4.02243551e+00],
#        [-7.40873586e+00, -8.10963125e+00],
#        [-6.89479662e+00, -2.39075343e+00],
#        [-1.83215596e+00,  1.45888609e+00],
#        [-1.53518519e+00,  9.14035890e-01],
#        [-9.69754218e+00, -4.30559839e+00],
#        [-7.56167627e+00,  6.67179314e+00],
#        [-1.11402307e+01, -4.30269127e+00],
#        [-3.26391855e+00,  1.63968000e+00],
#        [-8.13277764e+00, -1.85262143e+00],
#        [-5.30863573e+00,  7.98263093e+00],
#        [-6.31349128e+00, -4.70455781e+00],
#        [-5.15337806e+00, -2.67988492e+00],
#        [-2.84652599e-01,  3.41708214e+00],
#        [-6.83478745e+00, -7.39121692e+00],
#        [-1.98682939e+00,  1.39471494e+00],
#        [-9.48478268e+00, -4.25144138e+00],
#        [-7.73554447e+00, -7.77566432e+00],
#        [-1.01895481e+01, -4.84097751e+00],
#        [-7.03007040e+00,  9.51842763e+00],
#        [-1.75255446e+00,  3.58533582e+00],
#        [-5.63028993e+00,  7.48923602e+00],
#        [-9.36039872e-01,  3.38458841e+00],
#        [-5.25790464e-01,  3.30659860e+00],
#        [-6.72192434e+00, -1.86427775e+00],
#        [-1.83198811e+00,  3.52863145e+00],
#        [-1.27184365e+00,  1.52803950e-01],
#        [-1.57244072e+00,  3.47807577e+00],
#        [-9.71212518e+00, -3.06820738e+00],
#        [-1.61734616e+00,  4.98930508e+00],
#        [-1.36731055e+00,  3.40774886e+00],
#        [-2.77687025e+00,  4.64090557e+00],
#        [-1.07521104e+01, -2.70048039e+00],
#        [-2.25122029e+00,  6.74588808e-01],
#        [-9.87755355e+00, -3.33614544e+00],
#        [-2.88866847e+00,  4.01793773e+00],
#        [-2.24557082e+00,  1.72414052e-01],
#        [-6.29941273e+00, -3.86394708e+00],
#        [-1.19576436e+00,  1.52674632e+00],
#        [-1.17474527e+00,  3.60423477e+00],
#        [-5.40777019e+00,  8.85557461e+00],
#        [-6.64138783e+00, -8.07588804e+00],
#        [-5.00103984e+00, -1.12168371e+00],
#        [-4.75061644e+00,  7.93184144e+00],
#        [-2.76017908e+00,  5.55121358e+00],
#        [-1.59870030e+00,  2.58237128e+00],
#        [-7.44016713e+00, -8.79195851e+00],
#        [ 9.12215995e-01,  3.45575523e+00],
#        [-2.35122066e+00,  4.00973634e+00],
#        [-7.37108620e+00, -7.32525346e+00],
#        [-4.36999762e-01,  1.11434638e+00],
#        [-9.94690475e+00, -4.59034419e+00],
#        [-2.33080604e+00,  4.39382527e+00],
#        [-1.26278948e+00,  8.22901978e-01],
#        [-9.15872909e+00, -3.02224647e+00],
#        [-1.02582591e+00,  2.96331433e+00],
#        [-5.53423932e+00, -4.04248606e+00],
#        [-5.86596430e+00, -7.96807169e+00],
#        [-1.78245013e+00,  3.47072043e+00],
#        [-8.50899599e+00, -8.65769397e+00],
#        [-5.10000333e+00,  8.60679082e+00],
#        [-3.29470865e+00,  1.32687218e+00],
#        [-7.24290667e+00,  5.80166017e+00],
#        [-7.81213710e+00, -5.34984488e+00],
#        [-1.07448708e+01, -2.26089395e+00],
#        [-7.58703957e-01,  3.72276201e+00],
#        [-5.87130413e+00, -2.49520694e+00],
#        [-7.64791309e+00, -2.77362607e+00],
#        [-5.92424979e+00, -4.40106887e+00],
#        [-8.86608312e+00, -2.43353173e+00],
#        [-9.50919436e+00, -4.02892026e+00],
#        [-9.80679702e+00, -1.85309341e+00],
#        [-6.87832079e+00, -7.74317646e+00],
#        [-2.37476729e+00, -1.65850308e+00],
#        [-6.47326044e+00,  9.51722680e+00],
#        [-1.97451969e-01,  2.34634916e+00],
#        [-6.54101428e+00, -3.05617091e+00],
#        [-6.74924724e+00, -1.01754293e+01],
#        [-1.54407418e+00, -3.68006710e-01],
#        [-7.28721033e+00, -8.35398617e+00],
#        [-2.13320417e+00,  2.70736318e+00],
#        [-6.02140203e+00,  6.94498666e+00],
#        [ 2.42271161e-04,  5.14853403e+00],
#        [-7.57969185e-01,  4.90898421e+00],
#        [-1.02066067e+01, -3.36672536e+00],
#        [-2.34673261e+00,  3.56128423e+00],
#        [-6.86658246e+00, -8.03421946e+00],
#        [-5.25190521e+00,  5.93491039e+00]])

# %%
# Get the shape of the X values
X.shape
# Out:
# (100, 2)

# %%
# Print out the y values and get the shape.
print(y)
y.shape
# Out:
# [0 6 5 5 5 6 2 3 6 3 5 2 0 2 3 4 4 1 6 1 4 3 6 3 3 5 2 4 1 2 1 6 5 6 5 0 3
#  0 4 5 1 0 5 0 1 4 1 5 4 3 4 5 6 2 3 6 0 5 2 5 0 2 4 1 0 4 1 4 3 2 0 2 6 4
#  6 1 1 0 3 3 3 1 1 1 2 4 6 0 3 2 4 2 5 6 0 0 1 0 2 6]
# (100,)

# %%
# Transform the y variables into a single column.
y = y.reshape(-1, 1)

# %%
# Create a DataFrame with the synthetic data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])

# Add the y variables as the "Target" column.
df["Target"] = y

# Display the data
df
# Out:
#     Feature 1  Feature 2  Target
# 0   -1.927448   4.936845       0
# 1   -5.348194   7.803086       6
# 2   -0.629775   3.917924       5
# 3   -2.263026   4.605877       5
# 4    0.574590   1.808029       5
# ..        ...        ...     ...
# 95  -0.757969   4.908984       0
# 96 -10.206607  -3.366725       1
# 97  -2.346733   3.561284       0
# 98  -6.866582  -8.034219       2
# 99  -5.251905   5.934910       6
#
# [100 rows x 3 columns]

# %%
# Visualize the data
df.plot.scatter(x="Feature 1",
                y="Feature 2",
                c="Target",
                colormap="winter")
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Generate five synthetic clusters
X, y = make_blobs(
    centers=5, 
    n_features=2,
    random_state=1
)

# Transform the y variables into a single column.
y = y.reshape(-1, 1)

# %%
# Create a DataFrame with the synthetic data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])

# Add the y variables as the "Target" column.
df["Target"] = y

# Visualize the data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>
